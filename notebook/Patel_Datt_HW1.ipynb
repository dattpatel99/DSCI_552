# %% [markdown]
# <center><h1>Last_First_HW1</h1></center>
# <br>
# <center><font size="4">Vertebral Column Data</font></center>

# %% [markdown]
# ### (a) Download Data

# %% [markdown]
# Package imports

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import arff

# %% [markdown]
# Get the Vertebral Column Data Set

# %%
file_data = arff.load(open('../data/vertebral_column_data/column_2C_weka.arff'))
features = [x[0] for x in file_data['attributes']]
df = pd.DataFrame(data = file_data['data'], columns = features) # Creating the dataframe
df['classification'] = df['class'].map({'Normal':1,'Abnormal':0}) # altering values of class to 1 and 0 and adding a new column for it

# %% [markdown]
# ### (b) Pre-Processing and Exploratory Data Analysis

# %% [markdown]
# #### i. Scatterplots

# %%
sns.pairplot(df, hue='classification')

# %% [markdown]
# #### ii. Boxplots

# %%
# pelvic_incidence, pelvic_tilt, lumbar_lordosis_angle, sacral_slope, pelvic_radius, degree_spondylolisthesis
fig, axs = plt.subplots(nrows=6,ncols=1,figsize=(10,45))

# Title for the entire plot
fig.suptitle("Question 1bi",fontsize=15)

for i in range(0, 6):
    sns.boxplot(df, x='classification',y=features[i], ax= axs[i])
    axs[i].set_title("Plot {}: Classification vs {}".format(i+1, features[i]))

# %% [markdown]
# #### iii. Split Data Set

# %%
# Filtering data as per classification value
data_nor, data_ab = df[df['classification'] == 1], df[df['classification'] == 0]
# Randomly shuffling data
data_nor = data_nor.sample(frac=1)
data_ab = data_ab.sample(frac=1)
# Splitting the data
train_d = pd.concat([data_nor[:140],data_ab[:70]],axis=0)
test_d =  pd.concat([data_nor[140:],data_ab[70:]], axis=0)

# %% [markdown]
# ### (c) Classification

# %% [markdown]
# #### i. Euclidean Metric

# %% [markdown]
# #### ii. Test Data

# %% [markdown]
# #### iii. Learning Curve

# %% [markdown]
# ### (d) Other Metrics

# %% [markdown]
# #### i. Minkowski Distance.

# %% [markdown]
# ##### A. Manhattan Distance with p = 1.

# %% [markdown]
# ##### B. With log10(p) in {0.1, 0.2, 0.3, ... ,1}.

# %% [markdown]
# ##### C. Chebyshev Distance With p -> infinity.

# %% [markdown]
# #### ii. Mahalanobis Distance.

# %% [markdown]
# ### (e) Weighted Decision

# %% [markdown]
# ### (f) Training Error Rate
